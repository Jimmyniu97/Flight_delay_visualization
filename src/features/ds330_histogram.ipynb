# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/luca/desktop/airline-delay-and-cancellation-data-2009-2018/2018.csv")

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#       FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0  2018-01-01         UA               2429    EWR  DEN          1517
# 1  2018-01-01         UA               2427    LAS  SFO          1115
# 2  2018-01-01         UA               2426    SNA  DEN          1335
# 3  2018-01-01         UA               2425    RSW  ORD          1546
# 4  2018-01-01         UA               2424    ORD  ALB           630
#
#    DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  WHEELS_ON  TAXI_IN  \
# 0    1512.0       -5.0      15.0      1527.0     1712.0     10.0
# 1    1107.0       -8.0      11.0      1118.0     1223.0      7.0
# 2    1330.0       -5.0      15.0      1345.0     1631.0      5.0
# 3    1552.0        6.0      19.0      1611.0     1748.0      6.0
# 4     650.0       20.0      13.0       703.0      926.0     10.0
#
#    CRS_ARR_TIME  ARR_TIME  ARR_DELAY  CANCELLED CANCELLATION_CODE  DIVERTED  \
# 0          1745    1722.0      -23.0        0.0               NaN       0.0
# 1          1254    1230.0      -24.0        0.0               NaN       0.0
# 2          1649    1636.0      -13.0        0.0               NaN       0.0
# 3          1756    1754.0       -2.0        0.0               NaN       0.0
# 4           922     936.0       14.0        0.0               NaN       0.0
#
#    CRS_ELAPSED_TIME  ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  CARRIER_DELAY  \
# 0             268.0                250.0     225.0    1605.0            NaN
# 1              99.0                 83.0      65.0     414.0            NaN
# 2             134.0                126.0     106.0     846.0            NaN
# 3             190.0                182.0     157.0    1120.0            NaN
# 4             112.0                106.0      83.0     723.0            NaN
#
#    WEATHER_DELAY  NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY  Unnamed: 27
# 0            NaN        NaN             NaN                  NaN          NaN
# 1            NaN        NaN             NaN                  NaN          NaN
# 2            NaN        NaN             NaN                  NaN          NaN
# 3            NaN        NaN             NaN                  NaN          NaN
# 4            NaN        NaN             NaN                  NaN          NaN

# %%
df.OP_CARRIER.unique()
# Out:
# array(['UA', 'AS', '9E', 'B6', 'EV', 'F9', 'G4', 'HA', 'MQ', 'NK', 'OH',
#        'OO', 'VX', 'WN', 'YV', 'YX', 'AA', 'DL'], dtype=object)

# %%
df
# Out:
#             FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0        2018-01-01         UA               2429    EWR  DEN          1517
# 1        2018-01-01         UA               2427    LAS  SFO          1115
# 2        2018-01-01         UA               2426    SNA  DEN          1335
# 3        2018-01-01         UA               2425    RSW  ORD          1546
# 4        2018-01-01         UA               2424    ORD  ALB           630
# 5        2018-01-01         UA               2422    ORD  OMA          2241
# 6        2018-01-01         UA               2421    IAH  LAS           750
# 7        2018-01-01         UA               2420    DEN  CID          1324
# 8        2018-01-01         UA               2419    SMF  EWR          2224
# 9        2018-01-01         UA               2418    RIC  DEN          1601
# 10       2018-01-01         UA               2417    PDX  EWR          2240
# 11       2018-01-01         UA               2416    ORD  CLE          2059
# 12       2018-01-01         UA               2415    EWR  PDX           825
# 13       2018-01-01         UA               2414    EWR  ATL          1044
# 14       2018-01-01         UA               2413    ORD  BTV          2114
# 15       2018-01-01         UA               2412    MCO  LAX           653
# 16       2018-01-01         UA               2411    EWR  SMF          1810
# 17       2018-01-01         UA               2410    RSW  EWR          1250
# 18       2018-01-01         UA               2409    IAH  JAC           940
# 19       2018-01-01         UA               2408    TYS  EWR          1131
# 20       2018-01-01         UA               2406    EWR  TYS           830
# 21       2018-01-01         UA               2405    SFO  IAH           530
# 22       2018-01-01         UA               2404    RSW  ORD          1220
# 23       2018-01-01         UA               2403    SFO  HNL          1927
# 24       2018-01-01         UA               2402    JAC  EWR          1343
# 25       2018-01-01         UA               2400    BOS  SFO          1820
# 26       2018-01-01         UA               2399    ORD  MIA          1405
# 27       2018-01-01         UA               2398    MSY  EWR          2043
# 28       2018-01-01         UA               2397    MIA  IAH           900
# 29       2018-01-01         UA               2394    EWR  LAX          1500
# ...             ...        ...                ...    ...  ...           ...
# 7213416  2018-12-31         AA               1794    RDU  CLT          1817
# 7213417  2018-12-31         AA               1795    DSM  PHX           730
# 7213418  2018-12-31         AA               1796    CLT  TPA          1819
# 7213419  2018-12-31         AA               1797    BDL  PHL          1419
# 7213420  2018-12-31         AA               1797    PHL  BDL          1235
# 7213421  2018-12-31         AA               1798    CLT  RDU           925
# 7213422  2018-12-31         AA               1798    RDU  CLT          1103
# 7213423  2018-12-31         AA               1799    LAX  PHL           720
# 7213424  2018-12-31         AA               1800    CLT  BWI          2040
# 7213425  2018-12-31         AA               1801    BOS  CLT           611
# 7213426  2018-12-31         AA               1803    DCA  MIA          1737
# 7213427  2018-12-31         AA               1803    MIA  DCA          1400
# 7213428  2018-12-31         AA               1804    IAH  CLT           850
# 7213429  2018-12-31         AA               1805    CLT  DTW          1632
# 7213430  2018-12-31         AA               1806    TPA  PHL           653
# 7213431  2018-12-31         AA               1807    DFW  MCI          1725
# 7213432  2018-12-31         AA               1808    LAS  PHX           630
# 7213433  2018-12-31         AA               1809    PHL  CLT           500
# 7213434  2018-12-31         AA               1810    PHL  DFW           855
# 7213435  2018-12-31         AA               1811    CLT  TPA          1644
# 7213436  2018-12-31         AA               1812    PDX  PHX          1058
# 7213437  2018-12-31         AA               1812    PHX  PDX           825
# 7213438  2018-12-31         AA               1813    CLT  ATL          2100
# 7213439  2018-12-31         AA               1814    DFW  PHL          1955
# 7213440  2018-12-31         AA               1815    CLT  DCA          1321
# 7213441  2018-12-31         AA               1815    DCA  CLT          1534
# 7213442  2018-12-31         AA               1816    CLT  DFW          1751
# 7213443  2018-12-31         AA               1817    CLT  MEM          2015
# 7213444  2018-12-31         AA               1818    CLT  RDU          1300
# 7213445  2018-12-31         AA               1818    RDU  CLT          1435
#
#          DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  WHEELS_ON  TAXI_IN  \
# 0          1512.0       -5.0      15.0      1527.0     1712.0     10.0
# 1          1107.0       -8.0      11.0      1118.0     1223.0      7.0
# 2          1330.0       -5.0      15.0      1345.0     1631.0      5.0
# 3          1552.0        6.0      19.0      1611.0     1748.0      6.0
# 4           650.0       20.0      13.0       703.0      926.0     10.0
# 5          2244.0        3.0      15.0      2259.0        1.0      2.0
# 6           747.0       -3.0      14.0       801.0      854.0      6.0
# 7          1318.0       -6.0      11.0      1329.0     1554.0      6.0
# 8          2237.0       13.0      10.0      2247.0      627.0      9.0
# 9          1559.0       -2.0      12.0      1611.0     1748.0      8.0
# 10         2235.0       -5.0       9.0      2244.0      624.0      7.0
# 7213445    1443.0        8.0       8.0      1451.0     1535.0      7.0
#
#          CRS_ARR_TIME  ARR_TIME  ARR_DELAY  CANCELLED CANCELLATION_CODE  \
# 0                1745    1722.0      -23.0        0.0               NaN
# 1                1254    1230.0      -24.0        0.0               NaN
# 2                1649    1636.0      -13.0        0.0               NaN
# 3                1756    1754.0       -2.0        0.0               NaN
# 4                 922     936.0       14.0        0.0               NaN
# 5                  14       3.0      -11.0        0.0               NaN
# 6                 916     900.0      -16.0        0.0               NaN
# 7                1619    1600.0      -19.0        0.0               NaN
# 8                 638     636.0       -2.0        0.0               NaN
# 9                1813    1756.0      -17.0        0.0               NaN
# 10                647     631.0      -16.0        0.0               NaN
# 11               2311     120.0      129.0        0.0               NaN
# 12               1135    1109.0      -26.0        0.0               NaN
# 13               1318    1315.0       -3.0        0.0               NaN
# 14                 15     128.0       73.0        0.0               NaN
# 15                930    1025.0       55.0        0.0               NaN
# 16               2136    2201.0       25.0        0.0               NaN
# 17               1537    1606.0       29.0        0.0               NaN
# 18               1218    1200.0      -18.0        0.0               NaN
# 19               1333    1312.0      -21.0        0.0               NaN
# 20               1049    1055.0        6.0        0.0               NaN
# 21               1122    1054.0      -28.0        0.0               NaN
# 22               1430    1422.0       -8.0        0.0               NaN
# 23               2325    2250.0      -35.0        0.0               NaN
# 24               1959    2013.0       14.0        0.0               NaN
# 25               2148    2137.0      -11.0        0.0               NaN
# 26               1810    1806.0       -4.0        0.0               NaN
# 27                 34     101.0       27.0        0.0               NaN
# 28               1056    1054.0       -2.0        0.0               NaN
# 29               1820    1812.0       -8.0        0.0               NaN
# ...               ...       ...        ...        ...               ...
# 7213416          1925    1938.0       13.0        0.0               NaN
# 7213417          1009    1025.0       16.0        0.0               NaN
# 7213418          2005    1958.0       -7.0        0.0               NaN
# 7213419          1548    1526.0      -22.0        0.0               NaN
# 7213420          1336    1326.0      -10.0        0.0               NaN
# 7213421          1018    1007.0      -11.0        0.0               NaN
# 7213422          1211    1203.0       -8.0        0.0               NaN
# 7213423          1522    1442.0      -40.0        0.0               NaN
# 7213424          2206    2157.0       -9.0        0.0               NaN
# 7213425           846     849.0        3.0        0.0               NaN
# 7213426          2030    2018.0      -12.0        0.0               NaN
# 7213427          1629    1612.0      -17.0        0.0               NaN
# 7213428          1217    1154.0      -23.0        0.0               NaN
# 7213429          1828    1901.0       33.0        0.0               NaN
# 7213430           924     936.0       12.0        0.0               NaN
# 7213431          1856    1839.0      -17.0        0.0               NaN
# 7213432           842     838.0       -4.0        0.0               NaN
# 7213433           644     713.0       29.0        0.0               NaN
# 7213434          1205    1159.0       -6.0        0.0               NaN
# 7213435          1830    1839.0        9.0        0.0               NaN
# 7213436          1430    1422.0       -8.0        0.0               NaN
# 7213437          1017    1016.0       -1.0        0.0               NaN
# 7213438          2213    2207.0       -6.0        0.0               NaN
# 7213439          2357       6.0        9.0        0.0               NaN
# 7213440          1445    1422.0      -23.0        0.0               NaN
# 7213441          1714    1709.0       -5.0        0.0               NaN
# 7213442          1952    1953.0        1.0        0.0               NaN
# 7213443          2107    2118.0       11.0        0.0               NaN
# 7213444          1350    1404.0       14.0        0.0               NaN
# 7213445          1546    1542.0       -4.0        0.0               NaN
#
#          DIVERTED  CRS_ELAPSED_TIME  ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  \
#
ARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  SECURITY_DELAY  \
# 0                  NaN            NaN        NaN             NaN
# 1                  NaN            NaN        NaN             NaN
# 2                  NaN            NaN        NaN             NaN
# 3                  NaN            NaN        NaN             NaN
# 4                  NaN            NaN        NaN             NaN
# 5                  NaN            NaN        NaN             NaN
# 6                  NaN            NaN        NaN             NaN
# 7                  NaN            NaN        NaN             NaN
# 8                  NaN            NaN        NaN             NaN
# 9                  NaN            NaN        NaN             NaN
# 10                 NaN            NaN        NaN             NaN
# 11               121.0            0.0        8.0             0.0
# 12                 NaN            NaN        NaN             NaN
# 13                 NaN            NaN        NaN             NaN
# 14                 0.0           11.0        0.0             0.0
# 15                54.0            0.0        1.0             0.0
# 16                 7.0            0.0        0.0             0.0
# 17                29.0            0.0        0.0             0.0
# 18                 NaN            NaN        NaN             NaN
# 19                 NaN            NaN        NaN             NaN
# 20                 NaN            NaN        NaN             NaN
# 21                 NaN            NaN        NaN             NaN
# 22                 NaN            NaN        NaN             NaN
# 23                 NaN            NaN        NaN             NaN
# 24                 NaN            NaN        NaN             NaN
# 25                 NaN            NaN        NaN             NaN
# 26                 NaN            NaN        NaN             NaN
# 27                27.0            0.0        0.0             0.0
# 28                 NaN            NaN        NaN             NaN
# 29                 NaN            NaN        NaN             NaN
# ...                ...            ...        ...             ...
# 7213416            NaN            NaN        NaN             NaN
# 7213417            0.0            0.0       16.0             0.0
# 7213418            NaN            NaN        NaN             NaN
# 7213419            NaN            NaN        NaN             NaN
# 7213420            NaN            NaN        NaN             NaN
# 7213421            NaN            NaN        NaN             NaN
# 7213422            NaN            NaN        NaN             NaN
# 7213423            NaN            NaN        NaN             NaN
# 7213424            NaN            NaN        NaN             NaN
# 7213425            NaN            NaN        NaN             NaN
# 7213426            NaN            NaN        NaN             NaN
# 7213427            NaN            NaN        NaN             NaN
# 7213428            NaN            NaN        NaN             NaN
# 7213429           33.0            0.0        0.0             0.0
# 7213430            NaN            NaN        NaN             NaN
# 7213431            NaN            NaN        NaN             NaN
# 7213432            NaN            NaN        NaN             NaN
# 7213433           14.0            0.0       15.0             0.0
# 7213434            NaN            NaN        NaN             NaN
# 7213435            NaN            NaN        NaN             NaN
# 7213436            NaN            NaN        NaN             NaN
# 7213437            NaN            NaN        NaN             NaN
# 7213438            NaN            NaN        NaN             NaN
# 7213439            NaN            NaN        NaN             NaN
# 7213440            NaN            NaN        NaN             NaN
# 7213441            NaN            NaN        NaN             NaN
# 7213442            NaN            NaN        NaN             NaN
# 7213443            NaN            NaN        NaN             NaN
# 7213444            NaN            NaN        NaN             NaN
# 7213445            NaN            NaN        NaN             NaN
#
#          LATE_AIRCRAFT_DELAY  Unnamed: 27
# 0                        NaN          NaN
# 1                        NaN          NaN
# 2                        NaN          NaN
# 3                        NaN          NaN
# 4                        NaN          NaN
# 5                        NaN          NaN
# 6                        NaN          NaN
# 7                        NaN          NaN
# 8                        NaN          NaN
# 9                        NaN          NaN
# 10                       NaN          NaN
# 11                       0.0          NaN
# 12                       NaN          NaN
# 13                       NaN          NaN
# 14                      62.0          NaN
# 15                       0.0          NaN
# 16                      18.0          NaN
# 17                       0.0          NaN
# 18                       NaN          NaN
# 19                       NaN          NaN
# 20                       NaN          NaN
# 21                       NaN          NaN
# 22                       NaN          NaN
# 23                       NaN          NaN
# 24                       NaN          NaN
# 25                       NaN          NaN
# 26                       NaN          NaN
# 27                       0.0          NaN
# 28                       NaN          NaN
# 29                       NaN          NaN
# ...                      ...          ...
# 7213416                  NaN          NaN
# 7213417                  0.0          NaN
# 7213418                  NaN          NaN
# 7213419                  NaN          NaN
# 7213420                  NaN          NaN
# 7213421                  NaN          NaN
# 7213422                  NaN          NaN
# 7213423                  NaN          NaN
# 7213424                  NaN          NaN
# 7213425                  NaN          NaN
# 7213426                  NaN          NaN
# 7213427                  NaN          NaN
# 7213428                  NaN          NaN
# 7213429                  0.0          NaN
# 7213430                  NaN          NaN
# 7213431                  NaN          NaN
# 7213432                  NaN          NaN
# 7213433                  0.0          NaN
# 7213434                  NaN          NaN
# 7213435                  NaN          NaN
# 7213436                  NaN          NaN
# 7213437                  NaN          NaN
# 7213438                  NaN          NaN
# 7213439                  NaN          NaN
# 7213440                  NaN          NaN
# 7213441                  NaN          NaN
# 7213442                  NaN          NaN
# 7213443                  NaN          NaN
# 7213444                  NaN          NaN
# 7213445                  NaN          NaN
#
# [7213446 rows x 28 columns]

# %%
df['OP_CARRIER'].replace({
    'UA':'United Airlines',
    'AS':'Alaska Airlines',
    '9E':'Endeavor Air',
    'B6':'JetBlue Airways',
    'EV':'ExpressJet',
    'F9':'Frontier Airlines',
    'G4':'Allegiant Air',
    'HA':'Hawaiian Airlines',
    'MQ':'Envoy Air',
    'NK':'Spirit Airlines',
    'OH':'PSA Airlines',
    'OO':'SkyWest Airlines',
    'VX':'Virgin America',
    'WN':'Southwest Airlines',
    'YV':'Mesa Airline',
    'YX':'Republic Airways',
    'AA':'American Airlines',
    'DL':'Delta Airlines'
},inplace=True)

# %%
df.OP_CARRIER.unique()
# Out:
# array(['United Airlines', 'Alaska Airlines', 'Endeavor Air',
#        'JetBlue Airways', 'ExpressJet', 'Frontier Airlines',
#        'Allegiant Air', 'Hawaiian Airlines', 'Envoy Air',
#        'Spirit Airlines', 'PSA Airlines', 'SkyWest Airlines',
#        'Virgin America', 'Southwest Airlines', 'Mesa Airline',
#        'Republic Airways', 'American Airlines', 'Delta Airlines'],
#       dtype=object)

# %%
df.CANCELLED.sum()
# Out:
# 116584.0

# %%
df.CANCELLED.unique()
# Out:
# array([0., 1.])

# %%
canceled = df[(df['CANCELLED'] > 0)]

# %%
canceled.head(3)
# Out:
#          FL_DATE       OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  \
# 178   2018-01-01  United Airlines               2034    IAH  MFE
# 875   2018-01-01  United Airlines                864    LAS  SFO
# 1244  2018-01-01  United Airlines                488    MFE  IAH
#
#       CRS_DEP_TIME  DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  WHEELS_ON  \
# 178           1440       NaN        NaN       NaN         NaN        NaN
# 875           1744       NaN        NaN       NaN         NaN        NaN
# 1244          1726       NaN        NaN       NaN         NaN        NaN
#
#       TAXI_IN  CRS_ARR_TIME  ARR_TIME  ARR_DELAY  CANCELLED CANCELLATION_CODE  \
# 178       NaN          1601       NaN        NaN        1.0                 B
# 875       NaN          1926       NaN        NaN        1.0                 A
# 1244      NaN          1844       NaN        NaN        1.0                 B
#
#       DIVERTED  CRS_ELAPSED_TIME  ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  \
# 178        0.0              81.0                  NaN       NaN     316.0
# 875        0.0             102.0                  NaN       NaN     414.0
# 1244       0.0              78.0                  NaN       NaN     316.0
#
#       CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  SECURITY_DELAY  \
# 178             NaN            NaN        NaN             NaN
# 875             NaN            NaN        NaN             NaN
# 1244            NaN            NaN        NaN             NaN
#
#       LATE_AIRCRAFT_DELAY  Unnamed: 27
# 178                   NaN          NaN
# 875                   NaN          NaN
# 1244                  NaN          NaN

# %%
df.DEP_DELAY.head()
# Out:
# 0    -5.0
# 1    -8.0
# 2    -5.0
# 3     6.0
# 4    20.0
# Name: DEP_DELAY, dtype: float64

# %%
df.ARR_DELAY.head()
# Out:
# 0   -23.0
# 1   -24.0
# 2   -13.0
# 3    -2.0
# 4    14.0
# Name: ARR_DELAY, dtype: float64

# %%
df[df.ARR_DELAY > 0 ].count()
# Out:
# FL_DATE                2516050
# OP_CARRIER             2516050
# OP_CARRIER_FL_NUM      2516050
# ORIGIN                 2516050
# DEST                   2516050
# CRS_DEP_TIME           2516050
# DEP_TIME               2516050
# DEP_DELAY              2514853
# TAXI_OUT               2516050
# WHEELS_OFF             2516050
# WHEELS_ON              2516050
# TAXI_IN                2516050
# CRS_ARR_TIME           2516050
# ARR_TIME               2516050
# ARR_DELAY              2516050
# CANCELLED              2516050
# CANCELLATION_CODE            0
# DIVERTED               2516050
# CRS_ELAPSED_TIME       2516050
# ACTUAL_ELAPSED_TIME    2516049
# AIR_TIME               2516049
# DISTANCE               2516050
# CARRIER_DELAY          1352710
# WEATHER_DELAY          1352710
# NAS_DELAY              1352710
# SECURITY_DELAY         1352710
# LATE_AIRCRAFT_DELAY    1352710
# Unnamed: 27                  0
# dtype: int64

# %%
df = df[(df['ARR_DELAY'] > 0)]

# %%
# Minutes to hours 
df['ARR_DELAY'] = df['ARR_DELAY'] / 60

# Minutes to hours 
df['DEP_DELAY'] = df['DEP_DELAY'] / 60
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2516050 entries, 4 to 7213444
# Data columns (total 28 columns):
# FL_DATE                object
# OP_CARRIER             object
# OP_CARRIER_FL_NUM      int64
# ORIGIN                 object
# DEST                   object
# CRS_DEP_TIME           int64
# DEP_TIME               float64
# DEP_DELAY              float64
# TAXI_OUT               float64
# WHEELS_OFF             float64
# WHEELS_ON              float64
# TAXI_IN                float64
# CRS_ARR_TIME           int64
# ARR_TIME               float64
# ARR_DELAY              float64
# CANCELLED              float64
# CANCELLATION_CODE      object
# DIVERTED               float64
# CRS_ELAPSED_TIME       float64
# ACTUAL_ELAPSED_TIME    float64
# AIR_TIME               float64
# DISTANCE               float64
# CARRIER_DELAY          float64
# WEATHER_DELAY          float64
# NAS_DELAY              float64
# SECURITY_DELAY         float64
# LATE_AIRCRAFT_DELAY    float64
# Unnamed: 27            float64
# dtypes: float64(20), int64(3), object(5)
# memory usage: 556.7+ MB

# %%
type(df['FL_DATE'])
# Out:
# pandas.core.series.Series

# %%
pd.to_datetime(df.FL_DATE)
# Out:
# 4         2018-01-01
# 11        2018-01-01
# 14        2018-01-01
# 15        2018-01-01
# 16        2018-01-01
# 17        2018-01-01
# 20        2018-01-01
# 24        2018-01-01
# 27        2018-01-01
# 39        2018-01-01
# 56        2018-01-01
# 61        2018-01-01
# 62        2018-01-01
# 63        2018-01-01
# 66        2018-01-01
# 68        2018-01-01
# 69        2018-01-01
# 71        2018-01-01
# 73        2018-01-01
# 78        2018-01-01
# 80        2018-01-01
# 84        2018-01-01
# 87        2018-01-01
# 92        2018-01-01
# 93        2018-01-01
# 98        2018-01-01
# 104       2018-01-01
# 110       2018-01-01
# 111       2018-01-01
# 113       2018-01-01
#              ...
# 7213372   2018-12-31
# 7213374   2018-12-31
# 7213376   2018-12-31
# 7213377   2018-12-31
# 7213379   2018-12-31
# 7213389   2018-12-31
# 7213390   2018-12-31
# 7213391   2018-12-31
# 7213392   2018-12-31
# 7213396   2018-12-31
# 7213398   2018-12-31
# 7213399   2018-12-31
# 7213401   2018-12-31
# 7213402   2018-12-31
# 7213403   2018-12-31
# 7213404   2018-12-31
# 7213406   2018-12-31
# 7213412   2018-12-31
# 7213415   2018-12-31
# 7213416   2018-12-31
# 7213417   2018-12-31
# 7213425   2018-12-31
# 7213429   2018-12-31
# 7213430   2018-12-31
# 7213433   2018-12-31
# 7213435   2018-12-31
# 7213439   2018-12-31
# 7213442   2018-12-31
# 7213443   2018-12-31
# 7213444   2018-12-31
# Name: FL_DATE, Length: 2516050, dtype: datetime64[ns]

# %%
# Month variable
df['FL_DATE_month'] = pd.to_datetime(df['FL_DATE']).dt.month
# Weekday variable
df['FL_DATE_weekday'] = pd.to_datetime(df['FL_DATE']).dt.weekday_name
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
import matplotlib.pyplot as plt

# %%
# Arrival and departure delays by month of the year
plt.figure(figsize=(25, 12)).subplots_adjust(hspace = 0.5)

plt.subplot(2, 2 ,1)
df.groupby('FL_DATE_month').ARR_DELAY.sum().plot.bar().set_title('ARRIVAL delays by month')
plt.title('ARRIVAL delays by month', fontsize=16)
plt.ylabel('Hours', fontsize=14)
plt.xlabel('Month of the year', fontsize=14)

plt.subplot(2, 2 ,2)
df.groupby('FL_DATE_month').DEP_DELAY.sum().plot.bar()
plt.title('DEPARTURE delays by month', fontsize=16)
plt.ylabel('Hours', fontsize=14)
plt.xlabel('Month of the year', fontsize=14)

plt.show()

# %%
# Delays by airlines
plt.figure(figsize=(20, 6))
df.groupby('OP_CARRIER').ARR_DELAY.sum().sort_values(ascending=False).plot.bar()
plt.title('Delays by AIRLINES', fontsize=16)
plt.xlabel('Airline', fontsize=14)
plt.ylabel('Hours', fontsize=14)
plt.show()

# %%
# Delays by City
city_by_delay = df.groupby('ORIGIN').ARR_DELAY.sum().sort_values(ascending=False)
plt.figure(figsize=(20, 6))
city_by_delay[:15].plot.bar()
plt.title('Delays by City', fontsize=16)
plt.xlabel('City', fontsize=14)
plt.ylabel('Hours', fontsize=14)
plt.show()
